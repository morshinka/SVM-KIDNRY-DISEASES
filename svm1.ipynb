# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import  svm
from sklearn.metrics import  accuracy_score

# %%
df = pd.read_csv('fixed_data.csv')

# %%
df.sample()
# Out:
#        bp    sg   al   su  rbc  pc  pcc  ba    bgr    bu  ...  pcv  wc  rc  \
# 274  80.0  1.02  0.0  0.0    1   1    0   0  107.0  23.0  ...   32  90  34
#
#      htn  dm  cad  appet  pe  ane  classification
# 274    0   3    1      0   0    0               1
#
# [1 rows x 24 columns]

# %%
x = df.drop(columns='classification',axis=1)
y = df['classification']

# %%
print(x)
# Out:
#        bp     sg   al   su  rbc  pc  pcc  ba    bgr    bu  ...  hemo  pcv  wc  \
# 0    80.0  1.020  1.0  0.0    1   1    0   0  121.0  36.0  ...  15.4   32  72
# 1    50.0  1.020  4.0  0.0    1   1    0   0  121.0  18.0  ...  11.3   26  56
# 2    80.0  1.010  2.0  3.0    1   1    0   0  423.0  53.0  ...   9.6   19  70
# 3    70.0  1.005  4.0  0.0    1   0    1   0  117.0  56.0  ...  11.2   20  62
# 4    80.0  1.010  2.0  0.0    1   1    0   0  106.0  26.0  ...  11.6   23  68
# ..    ...    ...  ...  ...  ...  ..  ...  ..    ...   ...  ...   ...  ...  ..
# 395  80.0  1.020  0.0  0.0    1   1    0   0  140.0  49.0  ...  15.7   35  62
# 396  70.0  1.025  0.0  0.0    1   1    0   0   75.0  31.0  ...  16.5   42  72
# 397  80.0  1.020  0.0  0.0    1   1    0   0  100.0  26.0  ...  15.8   37  61
# 398  60.0  1.025  0.0  0.0    1   1    0   0  114.0  50.0  ...  14.2   39  67
# 399  80.0  1.025  0.0  0.0    1   1    0   0  131.0  18.0  ...  15.8   41  63
#
# ...

# %%
print(y)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    1
# 399    1
# Name: classification, Length: 400, dtype: int64

# %%
df.head()
# Out:
#      bp     sg   al   su  rbc  pc  pcc  ba    bgr    bu  ...  pcv  wc  rc  \
# 0  80.0  1.020  1.0  0.0    1   1    0   0  121.0  36.0  ...   32  72  34
# 1  50.0  1.020  4.0  0.0    1   1    0   0  121.0  18.0  ...   26  56  34
# 2  80.0  1.010  2.0  3.0    1   1    0   0  423.0  53.0  ...   19  70  34
# 3  70.0  1.005  4.0  0.0    1   0    1   0  117.0  56.0  ...   20  62  19
# 4  80.0  1.010  2.0  0.0    1   1    0   0  106.0  26.0  ...   23  68  27
#
#    htn  dm  cad  appet  pe  ane  classification
# 0    1   4    1      0   0    0               0
# 1    0   3    1      0   0    0               0
# 2    0   4    1      1   0    1               0
# 3    1   3    1      1   1    1               0
# 4    0   3    1      0   0    0               0
#
# [5 rows x 24 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, stratify=y, random_state=2)

# %%
clasifier = svm.SVC(kernel='linear')

# %%
clasifier.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
x_train_prediction = clasifier.predict(x_train)
train_accuracy = accuracy_score(x_train_prediction, y_train)
print('akurasi data latih : ', train_accuracy * 100)
# Out:
# akurasi data latih :  99.0625

# %%
x_test_prediction = clasifier.predict(x_test)
test_accuracy = accuracy_score(x_test_prediction, y_test)
print('akurasi data testing :', test_accuracy * 100)
# Out:
# akurasi data testing : 95.0

# %%
input_data = (80.0,1.025,0.0,0.0,1,1,0,0,122.0,33.0,0.9,146.0,3.9,13.9,36,87,29,0,3,1,0,0,0)
input_data_as_np_array = np.array(input_data)
input_data_reshape = input_data_as_np_array.reshape(1,-1)
prediction = clasifier.predict(input_data_reshape)
print(prediction)

if (prediction[0] == 0 ):
    print ('pasien tidak terkena batu ginjal',)
    print ('akurasi :', train_accuracy * 100)
else:
    print('pasien terkena batu ginjal')
    print ('akurasi :', train_accuracy * 100)
# Out:
# [1]
# pasien terkena batu ginjal
# akurasi : 99.0625
# C:\Users\tegar\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
import pickle

# %%
filename = 'kidney_disease.sav'
pickle.dump(clasifier, open(filename, 'wb'))
